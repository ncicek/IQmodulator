# %%
import skrf as rf

# %%
xfmr = rf.Network('11_turn_gigabit_eth_magnetic_trifilar_winding_50k-500M_sweep.s2p')
xfmr
# Out:
# 2-Port Network: '11_turn_gigabit_eth_magnetic_trifilar_winding_50k-500M_sweep',  50000.0-500000995.0 Hz, 10100 pts, z0=[50.+0.j 50.+0.j]

# %%
# %matplotlib inline
from pylab import *
rf.stylely()
# Out:
# C:\Users\nebst\Anaconda3\lib\site-packages\skrf\plotting.py:1441: UserWarning: Style includes a parameter, 'interactive', that is not related to style.  Ignoring
#   mpl.style.use(os.path.join(pwd, style_file))

# %%
xfmr.plot_s_db()
# Out:
# C:\Users\nebst\Anaconda3\lib\site-packages\skrf\mathFunctions.py:165: RuntimeWarning: divide by zero encountered in log10
#   out = 20 * npy.log10(input)
# C:\Users\nebst\Anaconda3\lib\site-packages\skrf\mathFunctions.py:165: RuntimeWarning: divide by zero encountered in log10
#   out = 20 * npy.log10(input)
# C:\Users\nebst\Anaconda3\lib\site-packages\skrf\mathFunctions.py:165: RuntimeWarning: divide by zero encountered in log10
#   out = 20 * npy.log10(input)
# C:\Users\nebst\Anaconda3\lib\site-packages\skrf\mathFunctions.py:165: RuntimeWarning: divide by zero encountered in log10
#   out = 20 * npy.log10(input)

# %%
xfmr.plot_s_smith()
