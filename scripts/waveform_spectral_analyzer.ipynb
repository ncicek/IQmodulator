# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

# %%
wave = pd.read_csv("../tb/cocotb/wave.csv").drop(['Unnamed: 0'], axis=1)
wave = wave["0"]

# %%
plt.magnitude_spectrum(wave, color ='green', Fs=100e6, scale='dB') 
plt.xlim(100,200e3)
# Out:
# (100.0, 200000.0)

# %%
plt.magnitude_spectrum(wave[0:10*8600], color ='green', Fs=100e6, scale='dB') 
plt.xlim(100,200e3)
# Out:
# (100.0, 200000.0)
