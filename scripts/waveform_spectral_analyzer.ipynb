# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

# %%
wave = pd.read_csv("../tb/cocotb/top_sim/wave.csv").drop(['Unnamed: 0'], axis=1)
wave = wave["0"]

# %%
plt.magnitude_spectrum(wave, color ='green', Fs=100e6, scale='dB') 
plt.ylim(-70,100)
plt.xlim(0,1e6)
# Out:
# (0.0, 1000000.0)
